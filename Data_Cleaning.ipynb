# %%
import json
import random
import os
import re
import pandas as pd

# %%
json_path = "./data/jsons/"

pattern_replace = r"\d+Embed"
pattern_split = r"\n*(\[.+\])\n*"
content = []

for filename in os.listdir(json_path):
    with open(json_path + filename, 'r') as f:
        songs = json.load(f)

    artist = filename.split('.')[0].replace('_', ' ')
    for song_name, song in songs.items():
        tag = ""
        song_clean = re.sub(pattern=pattern_replace, string=song, repl="")
        
        for part in re.split(pattern_split, song_clean):
            if re.match(pattern_split, part):
                tag = part
            else:
                content.append((artist, song_name, tag, part))
                tag = ""

# %%
df = pd.DataFrame(content, columns=["artist", "song", "tag", "content"])
df
# Out:
#                     artist        song                                  tag  \
# 0      5 Seconds of Summer  Youngblood
# 1      5 Seconds of Summer  Youngblood                      [Verse 1: Luke]
# 2      5 Seconds of Summer  Youngblood                   [Pre-Chorus: Luke]
# 3      5 Seconds of Summer  Youngblood                  [Chorus: Luke, All]
# 4      5 Seconds of Summer  Youngblood  [Verse 2: Luke, Luke & Ashton, All]
# ...                    ...         ...                                  ...
# 10140                 ZAYN      ​wRoNg   [Verse 2: Kehlani, Kehlani & ZAYN]
# 10141                 ZAYN      ​wRoNg        [Chorus: Both, ZAYN, Kehlani]
# 10142                 ZAYN      ​wRoNg            [Refrain: ZAYN & Kehlani]
# 10143                 ZAYN      ​wRoNg             [Bridge: ZAYN & Kehlani]
# 10144                 ZAYN      ​wRoNg       [Chorus: Both, ZAYN & Kehlani]
#
#                                                  content
# 0      146 ContributorsTranslationsEspañolPortuguêsYo...
# 1      Remember the words you told me\n"Love me till ...
# 2      You push and you push and I'm pullin' away\nPu...
# 3      Youngblood\nSay you want me, say you want me o...
# 4      Lately, our conversations\nEnd like it's the l...
# ...                                                  ...
# 10140  Here with you 'cause you got the right vibe\nS...
# 10141  You're looking in the wrong place for my love\...
# 10142  Don't stop what you're doin', what you're doin...
# 10143  I don't, I don't really know (What you're doin...
# 10144  You're looking in the wrong place for my love\...
#
# [10145 rows x 4 columns]

# %%
def clean(tag):
    pattern = r"\[(.+)\:"
    if ':' in tag:
        match = re.match(pattern, tag)
        if match:
            tag_ = match.group(1)
            return '[' + ''.join(filter(lambda x:not x.isdigit(), tag_)).strip() + ']'
    else:
        return ''.join(filter(lambda x:not x.isdigit(), tag)).strip()

# %%
df["tag_2"] = df["tag"].map(clean)
df = df[df["tag_2"]!=""]
df = df[df["content"]!=""]



df
# Out:
#                     artist        song                                  tag  \
# 1      5 Seconds of Summer  Youngblood                      [Verse 1: Luke]
# 2      5 Seconds of Summer  Youngblood                   [Pre-Chorus: Luke]
# 3      5 Seconds of Summer  Youngblood                  [Chorus: Luke, All]
# 4      5 Seconds of Summer  Youngblood  [Verse 2: Luke, Luke & Ashton, All]
# 5      5 Seconds of Summer  Youngblood                  [Chorus: Luke, All]
# ...                    ...         ...                                  ...
# 10140                 ZAYN      ​wRoNg   [Verse 2: Kehlani, Kehlani & ZAYN]
# 10141                 ZAYN      ​wRoNg        [Chorus: Both, ZAYN, Kehlani]
# 10142                 ZAYN      ​wRoNg            [Refrain: ZAYN & Kehlani]
# 10143                 ZAYN      ​wRoNg             [Bridge: ZAYN & Kehlani]
# 10144                 ZAYN      ​wRoNg       [Chorus: Both, ZAYN & Kehlani]
#
#                                                  content         tag_2
# 1      Remember the words you told me\n"Love me till ...       [Verse]
# 2      You push and you push and I'm pullin' away\nPu...  [Pre-Chorus]
# 3      Youngblood\nSay you want me, say you want me o...      [Chorus]
# 4      Lately, our conversations\nEnd like it's the l...       [Verse]
# 5      Youngblood\nSay you want me, say you want me o...      [Chorus]
# ...                                                  ...           ...
# 10140  Here with you 'cause you got the right vibe\nS...       [Verse]
# 10141  You're looking in the wrong place for my love\...      [Chorus]
# 10142  Don't stop what you're doin', what you're doin...     [Refrain]
# 10143  I don't, I don't really know (What you're doin...      [Bridge]
# 10144  You're looking in the wrong place for my love\...      [Chorus]
#
# [9066 rows x 5 columns]

# %%
df[["tag_2", "content"]].isnull().any()
# Out:
# tag_2      False
# content    False
# dtype: bool

# %%
df
# Out:
#                     artist        song                                  tag  \
# 1      5 Seconds of Summer  Youngblood                      [Verse 1: Luke]
# 2      5 Seconds of Summer  Youngblood                   [Pre-Chorus: Luke]
# 3      5 Seconds of Summer  Youngblood                  [Chorus: Luke, All]
# 4      5 Seconds of Summer  Youngblood  [Verse 2: Luke, Luke & Ashton, All]
# 5      5 Seconds of Summer  Youngblood                  [Chorus: Luke, All]
# ...                    ...         ...                                  ...
# 10140                 ZAYN      ​wRoNg   [Verse 2: Kehlani, Kehlani & ZAYN]
# 10141                 ZAYN      ​wRoNg        [Chorus: Both, ZAYN, Kehlani]
# 10142                 ZAYN      ​wRoNg            [Refrain: ZAYN & Kehlani]
# 10143                 ZAYN      ​wRoNg             [Bridge: ZAYN & Kehlani]
# 10144                 ZAYN      ​wRoNg       [Chorus: Both, ZAYN & Kehlani]
#
#                                                  content         tag_2
# 1      Remember the words you told me\n"Love me till ...       [Verse]
# 2      You push and you push and I'm pullin' away\nPu...  [Pre-Chorus]
# 3      Youngblood\nSay you want me, say you want me o...      [Chorus]
# 4      Lately, our conversations\nEnd like it's the l...       [Verse]
# 5      Youngblood\nSay you want me, say you want me o...      [Chorus]
# ...                                                  ...           ...
# 10140  Here with you 'cause you got the right vibe\nS...       [Verse]
# 10141  You're looking in the wrong place for my love\...      [Chorus]
# 10142  Don't stop what you're doin', what you're doin...     [Refrain]
# 10143  I don't, I don't really know (What you're doin...      [Bridge]
# 10144  You're looking in the wrong place for my love\...      [Chorus]
#
# [9066 rows x 5 columns]

# %%
test_songs = []

random.seed(0)

songs = df[["artist", "song"]].drop_duplicates()
for artist in songs["artist"].unique():
    test_songs.append(
        random.choice(
            songs[songs["artist"]==artist]["song"].array
    ))

test_songs[:10]
# Out:
# ['Ghost of You',
#  'Waterloo',
#  'Bang!',
#  'Boy In The Bubble',
#  'Growing Pains',
#  'Perfect',
#  '\u200bbreak up with your girlfriend, i’m bored',
#  'Not Your Barbie Girl',
#  'No Place',
#  'Oblivion']

# %%
from sklearn.model_selection import train_test_split

df_test = df[df["song"].isin(test_songs)]
df_train, df_val = train_test_split(df[~df["song"].isin(test_songs)], train_size=0.8)

# %%
df_train.sort_values(by=["artist", "song"]).to_csv("./data/datasets/train.csv", index=False)
df_test.sort_values(by=["artist", "song"]).to_csv("./data/datasets/test.csv", index=False)
df_val.sort_values(by=["artist", "song"]).to_csv("./data/datasets/val.csv", index=False)
